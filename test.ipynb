# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(20)
sample_s1=np.random.normal(np.array([1,3]),np.array([.1,.3]),(1000,2))
sample_s2=np.random.normal(np.array([3,1]),np.array([.1,.3]),(1000,2))
sample_1 = np.zeros([2000, 2])
sample_1_ss = np.zeros([2000, 2])
for i in range(len(sample_1)):
    if i%2 == 0:
        sample_1[i,:] = sample_s1[i//2,:]
    else:
        sample_1[i,:] = sample_s2[i//2,:]
for i in range(sample_1.shape[1]):
    sample_1_ss[:,i] = (sample_1[:,i]-sample_1[:,i].mean())/sample_1[:,i].std()

# %%
from neural_network import logregBGDbackpropagation
s = logregBGDbackpropagation(sample_1[:,0],sample_1[:,1],20,.1,50)
aa = s.run()
# Out:
# <built-in method all of numpy.ndarray object at 0x7fd170445830>
# 0.16881235525513436
# 8.577573110244408
# [[-1.47783506]
#  [ 0.0899472 ]]
# 0.2010190399739686
# 8.577573110244408
# [[-1.38061192]
#  [ 0.23774943]]
# 0.24566866244402033
# 8.577573110244408
# [[-1.26613015]
#  [ 0.41631998]]
# 0.3072490439130839
# 7.889217803667695
# [[-1.14768831]
#  [ 0.5818158 ]]
# 0.3741518100619527
# 6.479050017129957
# [[-1.04246647]
#  [ 0.68974988]]
# 0.4275754750645608
# 6.479050017129957
# [[-0.93239131]
#  [ 0.80202517]]
# 0.4851354584192423
# 6.062976294657053
# [[-0.82103862]
#  [ 0.91465996]]
# 0.5435065725091011
# -2.6087367159480492
# [[-0.73734384]
#  [ 0.9986668 ]]
# 0.586519227380845
# -4.127627502812909
# [[-0.65983766]
#  [ 1.07681598]]
# 0.6253120713505802
# -4.181644433913267
# [[-0.5845931]
#  [ 1.1524425]]
# 0.6614388933814894
# -4.181644433913267
# [[-0.51209421]
#  [ 1.22507237]]
# 0.6945040465355831
# -4.181644433913267
# [[-0.4428043 ]
#  [ 1.29429738]]
# ...

# %%
aa[0,0]
# Out:
# -1.243838163301244

# %%
aa[1,0]
# Out:
# 0.47801980370934705

# %%
np.random.seed(20)
sample_s1=np.random.normal(np.array([1,3]),np.array([.1,.3]),(1000,2))
sample_s2=np.random.normal(np.array([3,1]),np.array([.1,.3]),(1000,2))
sample_1 = np.zeros([2000, 2])
sample_1_ss = np.zeros([2000, 2])
for i in range(len(sample_1)):
    if i%2 == 0:
        sample_1[i,:] = sample_s1[i//2,:]
    else:
        sample_1[i,:] = sample_s2[i//2,:]
for i in range(sample_1.shape[1]):
    sample_1_ss[:,i] = (sample_1[:,i]-sample_1[:,i].mean())/sample_1[:,i].std()

# %%
x=np.linspace(-0,4,100)
plt.plot(x,aa[0,0]+aa[1,0]*x)
#plt.scatter(((sample_1_ss[:,0]-sample_1_ss[:,0].mean())/sample_1_ss[:,0].std())[0::2], ((sample_1_ss[:,1]-sample_1_ss[:,1].mean())/sample_1_ss[:,1].std())[0::2], color="green")
#plt.scatter(((sample_1_ss[:,0]-sample_1_ss[:,0].mean())/sample_1_ss[:,0].std())[1::2], ((sample_1_ss[:,1]-sample_1_ss[:,1].mean())/sample_1_ss[:,1].std())[1::2], color="purple")
plt.scatter(sample_1[:,0][0::2],sample_1[:,1][0::2], color="green")
plt.scatter(sample_1[:,0][1::2],sample_1[:,1][1::2], color="purple")
plt.show()

# %%
from neural_network import logregBGDbackpropagation

# %%
s = logregBGDbackpropagation(sample_1[:,0],sample_1[:,1],1000,.01,50)

# %%
s.run()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 s.run()
#
# File ~/ML/neural_network.py:31, in logregBGDbackpropagation.run(self)
#      29 self.build_model()
#      30 self.acitivtion_function()
# ---> 31 self.decision_treshold()
#      32 self.loss_function()
#      33 self.back_propation()
#
# File ~/ML/neural_network.py:54, in logregBGDbackpropagation.decision_treshold(self)
#      52 self.treshold = self.score_y.mean()
#      53 for i, _ in enumerate(self.score_y):
# ---> 54     if self.score_y[i, 1] < self.score_y.mean():
#      55         self.score_y_d[i, 1] = .05
#      56     else:
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
s.add_dummy_n()
s.initilzia_weight()
s.build_model()
s.acitivtion_function()
s.decision_treshold()
s.loss_function()
# Out:
# 4395.928676331138

# %%
from sympy import *
x, y, y_hat, z, w0, w1, w2, x1, x2, m, a = symbols('x y y_hat z w0 w1 w2 x1 x2 m a')
init_printing(use_unicode=True)

# %%
diff(1/(1+exp(-x)), x)
# Out:
#     -x
#    ℯ
# ──────────
#          2
# ⎛     -x⎞
# ⎝1 + ℯ  ⎠

# %%
y_hat = w0 + w1 * x1 + w2 * x2

# %%
z = 1/(1+exp(-y_hat))

# %%
simplify(diff(-(1/m)*((y)*log(y_hat, 2)+(1-y)*log(1-y_hat,2)), y_hat))
# Out:
#         y - yₕₐₜ
# ────────────────────────
# m⋅yₕₐₜ⋅(yₕₐₜ - 1)⋅log(2)

# %%
simplify(diff(-(1/m)*((y)*log(z, 2)+(1-y)*log(1-z,2)), w1))
# Out:
#    ⎛     w₀ + w₁⋅x₁ + w₂⋅x₂        w₀ + w₁⋅x₁ + w₂⋅x₂⎞
# x₁⋅⎝- y⋅ℯ                   - y + ℯ                  ⎠
# ──────────────────────────────────────────────────────
#             ⎛ w₀ + w₁⋅x₁ + w₂⋅x₂    ⎞
#           m⋅⎝ℯ                   + 1⎠⋅log(2)

# %%
simplify(diff(-(1/m)*((y)*log(z, 2)+(1-y)*log(1-z,2)), w2))
# Out:
#    ⎛     w₀ + w₁⋅x₁ + w₂⋅x₂        w₀ + w₁⋅x₁ + w₂⋅x₂⎞
# x₂⋅⎝- y⋅ℯ                   - y + ℯ                  ⎠
# ──────────────────────────────────────────────────────
#             ⎛ w₀ + w₁⋅x₁ + w₂⋅x₂    ⎞
#           m⋅⎝ℯ                   + 1⎠⋅log(2)

# %%
(np.array([[1,2,3,4]])*np.array([[1,2,3,4]])).T
# Out:
# array([[ 1],
#        [ 4],
#        [ 9],
#        [16]])

# %%
(np.array([[1,2,3,4]])*np.array([[1,2,3,4]]))
# Out:
# array([[ 1,  4,  9, 16]])

# %%
if (np.array([2,3,4])==np.array([2,3,4])).all:
    print(5)
# Out:
# 5

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib ipympl
def pltsin(ax, colors=['b']):
    x = np.linspace(0,1,100)
    if ax.lines:
        for line in ax.lines:
            line.set_xdata(x)
            y = np.random.random(size=(100,1))
            line.set_ydata(y)
    else:
        for color in colors:
            y = np.random.random(size=(100,1))
            ax.plot(x, y, color)
    fig.canvas.draw()

fig,ax = plt.subplots(1,1)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_xlim(0,1)
ax.set_ylim(0,1)
for f in range(5):
    pltsin(ax, ['b', 'r'])
    time.sleep(1)
# Out:
# ...
# <div id='d3965980-19b4-4057-b49e-b266de4969eb'></div>

# %%
# %matplotlib inline
import time
import pylab as plt
import numpy as np
from IPython import display

for i in range(10):
    plt.close()
    a = np.random.randint(100,size=100)
    b = np.random.randint(100,size=100)

    fig, ax = plt.subplots(2,1)
    ax[0].plot(a)
    ax[0].set_title('A')
    ax[1].plot(b)
    ax[1].set_title('B')

    display.clear_output(wait=True)
    display.display(plt.gcf())
    time.sleep(1.0)
